# %% [markdown]
# import

# %%
# import necessary libraries
import warnings
warnings.filterwarnings("ignore")
import nltk
from nltk.stem import WordNetLemmatizer
import json
import pickle

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
from keras.models import load_model

# create an object of WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# importing the GL Bot corpus file for pre-processing

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open("Train_Bot.json").read()
intents = json.loads(data_file)

# %% [markdown]
# data pre-processing

# %%
# preprocessing the json data
# tokenization
nltk.download('punkt')
nltk.download('wordnet')
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
# Out:
# [nltk_data] Downloading package punkt to C:\Users\vikas
# [nltk_data]     Shinde\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package wordnet to C:\Users\vikas
# [nltk_data]     Shinde\AppData\Roaming\nltk_data...

# %%
import nltk
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to C:\Users\vikas
# [nltk_data]     Shinde\AppData\Roaming\nltk_data...
# True

# %%
# lemmatize, lower each word and remove duplicates

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

# sort classes
classes = sorted(list(set(classes)))

# documents = combination between patterns and intents
print (len(documents), "documents")

# classes = intents
print (len(classes), "classes", classes)

# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

# creating a pickle file to store the Python objects which we will use while predicting
pickle.dump(words,open('words.pkl','wb')) 
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 128 documents
# 8 classes ['Bot', 'Exit', 'Intro', 'NN', 'Olympus', 'Profane', 'SL', 'Ticket']
# 158 unique lemmatized words ['a', 'able', 'access', 'activation', 'ada', 'adam', 'aifl', 'aiml', 'am', 'an', 'ann', 'anyone', 'are', 'artificial', 'backward', 'bad', 'bagging', 'batch', 'bayes', 'belong', 'best', 'blended', 'bloody', 'boosting', 'bot', 'buddy', 'classification', 'contact', 'create', 'cross', 'cya', 'day', 'deep', 'did', 'diffult', 'do', 'ensemble', 'epoch', 'explain', 'first', 'for', 'forest', 'forward', 'from', 'function', 'good', 'goodbye', 'gradient', 'great', 'hate', 'have', 'hell', 'hello', 'help', 'helped', 'hey', 'hi', 'hidden', 'hour', 'how', 'hyper', 'i', 'imputer', 'in', 'intelligence', 'is', 'jerk', 'joke', 'knn', 'later', 'layer', 'learner', 'learning', 'leaving', 'link', 'listen', 'logistic', 'lot', 'machine', 'me', 'ml', 'my', 'naive', 'name', 'nb', 'net', 'network', 'neural', 'no', 'not', 'of', 'olympus', 'olypus', 'on', 'online', 'operation', 'opertions', 'otimizer', 'parameter', 'piece', 'please', 'pm', 'problem', 'propagation', 'random', 'regression', 'relu', 'screw', 'see', 'sgd', 'shit', 'sigmoid', 'sl', 'smart', 'softmax', 'solution', 'solved', 'stupid', 'supervised', 'svm', 'talking', 'teach', 'techb=niques', 'technique', 'thank', 'thanks', 'the', 'there', 'think', 'ticket', 'time', 'to', 'ton', 'too', 'tool', 'unable', 'understand', 'up', 'use', 'useless', 'validation', 'very', 'visible', 'wasted', 'weight', 'what', 'whats', 'when', 'who', 'whom', 'window', 'with', 'work', 'working', 'ya', 'yo', 'you', 'your']

# %% [markdown]
# training data

# %%
# create our training data
training = []

# create an empty array for our output
output_empty = [0] * len(classes)

# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
   
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

# shuffle features and converting it into numpy arrays
random.shuffle(training)
training = np.array(training)

# create train and test lists
train_x = list(training[:,0])
train_y = list(training[:,1])

print("Training data created")
# Out:
# Training data created

# %% [markdown]
# nn model

# %%
# Create NN model to predict the responses
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot.h5', hist) # we will pickle this model to use in the future
print("\n")
print("*"*50)
print("\nModel Created Successfully!")
# Out:
# Epoch 1/200
# 26/26 [==============================] - 0s 1ms/step - loss: 2.0440 - accuracy: 0.2109
# Epoch 2/200
# 26/26 [==============================] - 0s 1ms/step - loss: 1.9556 - accuracy: 0.2344
# Epoch 3/200
# 26/26 [==============================] - 0s 1ms/step - loss: 1.9075 - accuracy: 0.2578
# Epoch 4/200
# 26/26 [==============================] - 0s 1ms/step - loss: 1.8458 - accuracy: 0.2969
# Epoch 5/200
# 26/26 [==============================] - 0s 1ms/step - loss: 1.7233 - accuracy: 0.4219
# Epoch 6/200
# 26/26 [==============================] - 0s 1ms/step - loss: 1.6182 - accuracy: 0.3594
# Epoch 7/200
# 26/26 [==============================] - 0s 1ms/step - loss: 1.4898 - accuracy: 0.5156
# Epoch 8/200
# 26/26 [==============================] - 0s 1ms/step - loss: 1.3605 - accuracy: 0.5781
# Epoch 9/200
# 26/26 [==============================] - 0s 1ms/step - loss: 1.2080 - accuracy: 0.5781
# Epoch 10/200
# 26/26 [==============================] - 0s 2ms/step - loss: 1.0890 - accuracy: 0.6484
# Epoch 11/200
# 26/26 [==============================] - 0s 1ms/step - loss: 1.0280 - accuracy: 0.6406
# Epoch 12/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.8798 - accuracy: 0.6797
# Epoch 13/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.8148 - accuracy: 0.7188
# Epoch 14/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.8072 - accuracy: 0.7500
# Epoch 15/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.7359 - accuracy: 0.8047
# Epoch 16/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.5462 - accuracy: 0.8438
# Epoch 17/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5900 - accuracy: 0.7969
# Epoch 18/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.5872 - accuracy: 0.8281
# Epoch 19/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.3498 - accuracy: 0.9219
# Epoch 20/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4187 - accuracy: 0.8750
# Epoch 21/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.3492 - accuracy: 0.9219
# Epoch 22/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.3417 - accuracy: 0.9141
# Epoch 23/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.2791 - accuracy: 0.9297
# Epoch 24/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.2530 - accuracy: 0.9453
# Epoch 25/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.2233 - accuracy: 0.9297
# Epoch 26/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.2224 - accuracy: 0.9609
# Epoch 27/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1701 - accuracy: 0.9531
# Epoch 28/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.2480 - accuracy: 0.9297
# Epoch 29/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1779 - accuracy: 0.9688
# Epoch 30/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.2102 - accuracy: 0.9453
# Epoch 31/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.2002 - accuracy: 0.9375
# Epoch 32/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1282 - accuracy: 0.9766
# Epoch 33/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1604 - accuracy: 0.9609
# Epoch 34/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1136 - accuracy: 0.9688
# Epoch 35/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1350 - accuracy: 0.9609
# Epoch 36/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1300 - accuracy: 0.9766
# Epoch 37/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1391 - accuracy: 0.9766
# Epoch 38/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0936 - accuracy: 0.9688
# Epoch 39/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1374 - accuracy: 0.9609
# Epoch 40/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0567 - accuracy: 0.9922
# Epoch 41/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0907 - accuracy: 0.9844
# Epoch 42/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0811 - accuracy: 0.9844
# Epoch 43/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0884 - accuracy: 0.9844
# Epoch 44/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0855 - accuracy: 0.9844
# Epoch 45/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0895 - accuracy: 0.9766
# Epoch 46/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1656 - accuracy: 0.9609
# Epoch 47/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0590 - accuracy: 0.9922
# Epoch 48/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1211 - accuracy: 0.9375
# Epoch 49/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0572 - accuracy: 1.0000
# Epoch 50/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1044 - accuracy: 0.9688
# Epoch 51/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0493 - accuracy: 0.9922
# Epoch 52/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0716 - accuracy: 0.9844
# Epoch 53/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0433 - accuracy: 0.9922
# Epoch 54/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0932 - accuracy: 0.9844
# Epoch 55/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.2018 - accuracy: 0.9375
# Epoch 56/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0485 - accuracy: 1.0000
# Epoch 57/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0745 - accuracy: 0.9922
# Epoch 58/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0535 - accuracy: 0.9844
# Epoch 59/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0558 - accuracy: 0.9844
# Epoch 60/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0566 - accuracy: 0.9922
# Epoch 61/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0327 - accuracy: 0.9922
# Epoch 62/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0357 - accuracy: 0.9922
# Epoch 63/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0749 - accuracy: 0.9688
# Epoch 64/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0394 - accuracy: 0.9922
# Epoch 65/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0709 - accuracy: 0.9844
# Epoch 66/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 67/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0703 - accuracy: 0.9766
# Epoch 68/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0328 - accuracy: 1.0000
# Epoch 69/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 70/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0654 - accuracy: 0.9844
# Epoch 71/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0446 - accuracy: 0.9844
# Epoch 72/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 73/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0299 - accuracy: 0.9922
# Epoch 74/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0495 - accuracy: 0.9688
# Epoch 75/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0433 - accuracy: 0.9844
# Epoch 76/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0565 - accuracy: 0.9844
# Epoch 77/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0331 - accuracy: 0.9922
# Epoch 78/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0652 - accuracy: 0.9766
# Epoch 79/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 80/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 81/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0296 - accuracy: 0.9922
# Epoch 82/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0330 - accuracy: 0.9922
# Epoch 83/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0284 - accuracy: 0.9922
# Epoch 84/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0279 - accuracy: 0.9922
# Epoch 85/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 86/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0518 - accuracy: 0.9922
# Epoch 87/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 88/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0231 - accuracy: 0.9922
# Epoch 89/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0353 - accuracy: 0.9922
# Epoch 90/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0359 - accuracy: 0.9922
# Epoch 91/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 92/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 93/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0261 - accuracy: 1.0000
# Epoch 94/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 95/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1014 - accuracy: 0.9844
# Epoch 96/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0535 - accuracy: 0.9844
# Epoch 97/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 98/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 99/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0313 - accuracy: 0.9922
# Epoch 100/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0305 - accuracy: 0.9844
# Epoch 101/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 102/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0318 - accuracy: 0.9922
# Epoch 103/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 104/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0259 - accuracy: 0.9922
# Epoch 105/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0522 - accuracy: 0.9844
# Epoch 106/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0360 - accuracy: 0.9844
# Epoch 107/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0316 - accuracy: 1.0000
# Epoch 108/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 109/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0243 - accuracy: 0.9922
# Epoch 110/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0238 - accuracy: 0.9922
# Epoch 111/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 112/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 113/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 114/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 115/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0344 - accuracy: 0.9922
# Epoch 116/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0134 - accuracy: 0.9922
# Epoch 117/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 118/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0295 - accuracy: 1.0000
# Epoch 119/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 120/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 121/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 122/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 123/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0246 - accuracy: 0.9922
# Epoch 124/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0504 - accuracy: 0.9844
# Epoch 125/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0380 - accuracy: 0.9922
# Epoch 126/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0206 - accuracy: 0.9922
# Epoch 127/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0428 - accuracy: 0.9844
# Epoch 128/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0286 - accuracy: 0.9922
# Epoch 129/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0256 - accuracy: 0.9922
# Epoch 130/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 131/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 132/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 133/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 134/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 135/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0454 - accuracy: 0.9922
# Epoch 136/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0297 - accuracy: 0.9844
# Epoch 137/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0274 - accuracy: 0.9922
# Epoch 138/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 139/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 140/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 141/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 142/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 143/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 144/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 145/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 146/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0302 - accuracy: 0.9922
# Epoch 147/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 148/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0177 - accuracy: 0.9922
# Epoch 149/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0285 - accuracy: 0.9922
# Epoch 150/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0174 - accuracy: 0.9922
# Epoch 151/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 152/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0379 - accuracy: 0.9922
# Epoch 153/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0273 - accuracy: 0.9922
# Epoch 154/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0301 - accuracy: 0.9766
# Epoch 155/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 156/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 157/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 158/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 159/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 160/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 161/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 162/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 163/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 164/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0420 - accuracy: 0.9844
# Epoch 165/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0227 - accuracy: 0.9922
# Epoch 166/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 167/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 168/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 169/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 170/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0162 - accuracy: 0.9922
# Epoch 171/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0145 - accuracy: 0.9922
# Epoch 172/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 173/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 174/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 175/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0307 - accuracy: 0.9922
# Epoch 176/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 177/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0214 - accuracy: 0.9922
# Epoch 178/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 179/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 180/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 181/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 182/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 183/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 184/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0263 - accuracy: 0.9922
# Epoch 185/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 186/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0310 - accuracy: 0.9844
# Epoch 187/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 188/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0162 - accuracy: 0.9922
# Epoch 189/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 190/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 191/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0168 - accuracy: 0.9922
# Epoch 192/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0265 - accuracy: 0.9922
# Epoch 193/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0139 - accuracy: 0.9922
# Epoch 194/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 0.9922
# Epoch 195/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 196/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.9922
# Epoch 197/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 198/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0657 - accuracy: 0.9922
# Epoch 199/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0152 - accuracy: 0.9922
# Epoch 200/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0077 - accuracy: 1.0000
#
#
# **************************************************
#
# Model Created Successfully!

# %% [markdown]
# pickled model for prediction

# %%
# load the saved model file
model = load_model('chatbot.h5')
intents = json.loads(open("Train_Bot.json").read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):

    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words


# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):

    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)

    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words) 
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
               
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
   
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    error = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>error]
    
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
# function to get the response from the model

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

# function to predict the class and get the response

def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    return res

# %%
# function to start the chat bot which will continue till the user type 'end'

def start_chat():
    print("Bot: This is Sophie! Your Personal Assistant.\n\n")
    while True:
        inp = str(input()).lower()
        if inp.lower()=="end":
            break
        if inp.lower()== '' or inp.lower()== '*':
            print('Please re-phrase your query!')
            print("-"*50)
        else:
            print(f"Bot: {chatbot_response(inp)}"+'\n')
            print("-"*50)

# %% [markdown]
# execution

# %%
start_chat()
# Out:
# Bot: This is Sophie! Your Personal Assistant.
#
#
# 1/1 [==============================] - 0s 29ms/step
# Bot: Hello! how can i help you ?
#
# --------------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# Bot: I am your virtual learning assistant
#
# --------------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# Bot: Please use respectful words
#
# --------------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# Bot: Link: Machine Learning wiki
#
# --------------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# Bot: Link: Machine Learning wiki
#
# --------------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# Bot: I am your virtual learning assistant
#
# --------------------------------------------------

# %% [markdown]
# Tkinter App

# %%
import random
import tkinter as tk
from tkinter import *

root=tk.Tk()
filename="Chat Bot"
root.title(f"Chat Bot")
root.geometry('500x400')
root.resizable(False, False)
message=tk.StringVar()

chat_win=Frame(root,bd=1,bg='white',width=50,height=8)
chat_win.place(x=6,y=6,height=300,width=488)

textcon=tk.Text(chat_win,bd=1,bg='white',width=50,height=8)
textcon.pack(fill="both",expand=True)

mes_win=Entry(root,width=30,xscrollcommand=True,textvariable=message)
mes_win.place(x=6,y=310,height=60,width=380)
mes_win.focus()

textcon.config(fg='black')
textcon.tag_config('usr',foreground='black')
textcon.insert(END,"Bot: This is Sophie! Your Personal Assistant.\n\n")
mssg=mes_win.get()

exit_list = ['exit','break','quit','see you later','chat with you later','end the chat','bye','ok bye']

def greet_res(text):
    text=text.lower()
    bot_greet=['hi','hello','hola','hey','howdy']
    usr_greet=['hi','hey','hello','hola','greetings','wassup','whats up']
    for word in text.split():
        if word in usr_greet:
            return random.choice(bot_greet)

def send_msz(event=None):
    usr_input = message.get()
    usr_input = usr_input.lower()
    textcon.insert(END, f'You: {usr_input}'+'\n','usr')
    if usr_input in exit_list:
        textcon.config(fg='black')
        textcon.insert(END,"Bot: Ok bye! Chat with you later\n")
        return root.destroy()
    else:
        textcon.config(fg='black')
        if greet_res(usr_input) != None:
            lab=f"Bot: {greet_res(usr_input)}"+'\n'
            textcon.insert(END,lab)
            mes_win.delete(0,END)
        else:
            lab = f"Bot: {chatbot_response(usr_input)}"+'\n'
            textcon.insert(END,lab)
            mes_win.delete(0,END)

button_send=Button(root,text='Send',bg='dark green',activebackground='grey',command=send_msz,width=12,height=5,font=('Arial'))
button_send.place(x=376,y=310,height=60,width=110)
root.bind('<Return>', send_msz,button_send)
root.mainloop()
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
